# %% [markdown]
# # Init

# %%
import numpy as np
from copy import deepcopy
import gc
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from torch import nn
import torch 
import torch.nn.functional as F
from torch.utils.data import DataLoader
import transformers
from transformers import AutoModelForCausalLM, AutoTokenizer
from datasets import load_dataset

from speaking_probes.generate import (extract_gpt_parameters, extract_gpt_j_parameters, speaking_probe, encode)
from speaking_probes.extra import top_tokens, corpus_search
# %reload_ext autoreload
# %autoreload 2

# %%
model_name = 'gpt2-medium'#'EleutherAI/gpt-j-6B' #  
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
model = AutoModelForCausalLM.from_pretrained(model_name)

# %% [markdown]
# ## Extract Parameters

# %%
model_params = extract_gpt_parameters(model, full=True)

emb = model_params.emb
d_int = model_params.d_int
ff_keys = model_params.ff_keys
ff_values = model_params.ff_values
W_Q_heads = model_params.W_Q_heads
W_K_heads = model_params.W_K_heads
W_V_heads = model_params.W_V_heads
W_O_heads = model_params.W_O_heads
mu = emb.mean(1)

# %% [markdown]
# # Speaking Probes

# %%
model.parallelize()

# %%
prompt = "The term \" <neuron>\" means"

# %%
print(prompt)
decoded = speaking_probe(model, model_params, tokenizer, prompt, 
                         (emb[:, tokenizer.encode(' children')[0]].to(model.device) + 
                          emb[:, tokenizer.encode(' dog')[0]].to(model.device)),
                         repetition_penalty=2., num_generations=20,
                         min_length=1, do_sample=True, # length_penalty=-0.2,
                         max_new_tokens=50, temperature=.5)

print('\n')
for i in range(len(decoded)):
    print("generate:", decoded[i])
    print('')
    print("""~~~~~~~~~~~~~~~~~~""" * 5)   
    print('')
# Out:
# The term " <neuron>" means
#
#
# generate: The term " <neuron>" means a person under the age of 18 years.
#  The terms are used in this chapter as follows: (1) A child shall be considered to have attained legal maturity when he or she has reached an understanding with his parent, guardian and other persons that
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal that is capable of walking on two legs, but not a dog.
#             The phrase 'the children' refers to those who were born before the adoption law was changed in 1996 and are now considered as age 18 or 19 years old
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any member of the genus Canis familiarus, but does not include chimpanzees or gorillas.
#  (2) (a)(i), in paragraph 1, is used to mean a dog that has been domesticated by human beings and whose natural
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any of the following: (a) A person who is under 18 years old, but not more than 17; and
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal or human being, whether a domestic pet (as defined in section 2 of chapter 8), wild dog/cat, ferret / rabbit and so forth;
# - includes all domesticated animals except those that are not protected as pets by the
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal of the genus Canis familiarus, including but not limited to dogs.
#  (2) The terms: "(1)(a),(b)" and ("1A") mean a dog; or
# - A person who is under 18
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any person under the age of eighteen years who is not a member or parent of an animal.
#  (b) Each dog shall be confined in such manner as to prevent its escape, and at all times when it may attack another human being for which
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal that has been domesticated.
# A dog is defined as a member of the family Dogidae, and includes all dogs belonging to this subfamily (except those owned by non-domestication groups). The word can be used with reference
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any individual under the age of sixteen years, and includes a child who is dependent on or has been adopted by another person;
# .
#  (c) If there are two children living in one household that share custody with each other for at least
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a person under the age of eighteen years, and any other animal or bird that is not ordinarily kept as an amusement.
#  The phrase shall also include horse-drawn vehicles operated by horses for hire to transport animals on public roads within this state; motor
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal which is not a member of the family Canidae.
#  (b) The following definitions shall apply to dogs, cats and other domesticated animals: 1. A dog or cat may be considered domestic if it has been kept in such confinement
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal, bird or reptile. This definition does not include a pet dog that is kept for its own protection and comfort as an emergency veterinary service provider by the owner of such animal under Section 2-5 of this article."
# 1) What
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a person who is under the age of eighteen years, but not more than twenty-one. A juvenile may be adjudged to have committed an offense if he or she has been convicted at any time during his/her lifetime and was previously sentenced by
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal that is not a dog and which, in the ordinary course of its life or activity (whether domestic animals) has been raised for human nutrition.
#  to be used as an adjective; by some persons it may mean. To have acquired this
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a child under the age of 18 years.
#  (b) The provisions in this section shall not apply to: 1. any person who is an employee, agent or representative thereof; 2 ; and 3, 4 if such employment relationship has been terminated
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a person who is under the age of 18 years and does not represent an immediate family member.
# - No child, grandparent or spouse shall purchase any firearm unless it has been registered with us prior to such transaction; provided that if no registration was
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a person under the age of 18 years.
#  (2) A child's presence in this state is not deemed to be an admission or waiver for purposes on which children may stand trial by jury, unless such court finds that: 1. There has
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means any animal or bird that is not a domestic pet.
#
#
#     <!--iframe--> --------------------------/ -->
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means every person under the age of 18 years and includes: (a) any dog, cat or other animal that is not a member thereof;
# - all dogs owned by an individual who owns more than one pet in common to which he/she has
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# generate: The term " <neuron>" means a person under the age of eighteen years, who has not attained twenty-five (25) years.
#
#
#     <!--iframe--> 
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~

# %% [markdown]
# ## Comparison

# %% [markdown]
# ### Embedding Space

# %%
neuron = ff_keys[21, 86].to(emb.device)

# %%
top_tokens(neuron @ emb, tokenizer=tokenizer, k=40)
# Out:
# ['IDs',
#  'identifiers',
#  'surname',
#  'surn',
#  'identifier',
#  'initials',
#  '#Registered',
#  'NAME',
#  '#names',
#  'pseudonym',
#  '#codes',
#  'nomine',
#  'names',
#  'username',
#  '#IDs',
#  'ID',
#  'registration',
#  '#76561',
#  '#soDeliveryDate',
#  '#ADRA',
#  'CLSID',
#  'numbering',
#  '#ername',
#  '#address',
#  'addresses',
#  'codes',
#  '#Names',
#  'regist',
#  'name',
#  'Names',
#  '#Address',
#  '#name',
#  'Registration',
#  '#Profile',
#  'Codes',
#  'aliases',
#  '#registered',
#  'nickname',
#  '#wcsstore',
#  '#isSpecialOrderable']

# %%
top_tokens(neuron @ F.normalize(emb, dim=0), tokenizer=tokenizer)
# Out:
# ['purchasing',
#  'installation',
#  '#buy',
#  'font',
#  'execution',
#  'clock',
#  'buying',
#  'buys',
#  'money',
#  'sale',
#  'purchase',
#  'buy',
#  'button',
#  'clicking',
#  'connecting',
#  'committee',
#  'connect',
#  'transmission',
#  'interaction',
#  '#budget']

# %% [markdown]
# ### Corpus Search

# %%
corpus = load_dataset("wikipedia", "20220301.en", split=f'train')
corpus = corpus.shuffle().select(range(12_000))['text']
# Out:
# Found cached dataset wikipedia (/home/guydar/.cache/huggingface/datasets/wikipedia/20220301.en/2.0.0/aa542ed919df55cc5d3347f42dd4521d05ca68751f50dbc32bae2a7f1e167559)

# %%
i1, i2 = 2, 1
results = corpus_search(model2, tokenizer, corpus, layer_path=f'transformer.h.{i1}.mlp.c_fc', # fc_in
                        dim_idx=i2, k=100, batch_size=64, normalize=True)
# Out:
#   0%|          | 0/188 [00:00<?, ?it/s]
# removing hook..

# %%
for sent, idx in results:
    # idx = idx.item()
    tokens = tokenizer.tokenize(sent)
    min_idx = max(0, idx-20)
    max_idx = min(len(tokens), idx+10)
    
    tokens = [*tokens[min_idx:idx], '@@', tokens[idx], '@@',  *tokens[idx+1:max_idx]]
    print(tokenizer.convert_tokens_to_string(tokens))
    print("""~~~~~~~~~~~~~~~~~~~~""" * 5)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (3467 > 1024). Running this sequence through the model will result in indexing errors
#  of a semi-automatic firearm to fire ammunition cartridges in rapid succession.
#
# The legality of bump@@ stocks@@ in the United States came under question following the
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  (born March 8, 1973) is an American producer, mixer, engineer, re-recording@@ mixer@@, sound designer and musician.   He
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# , the term refers to non-criminal law. The law relating to civil wrongs and quasi-@@contract@@s is part of the civil law. The
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Torch is a hardcore/metal band from Tr@@ond@@heim, Norway.
#
# Musical style
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  rules (informal rules-in-use and norms) and also theoretical rules (formal@@ rules@@ and law). This field deals with how individuals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# -length studio album was released on April 9, 2013 -- All Things New, which was with B@@EC@@ Recordings, and was produced by Casey Brown
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Dino Manelli
#  Private Robert "Rebel" Ralston
#  Private Jonathan "Junior"@@ Jun@@iper
#  Private Percival "Pinky
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# , optoelectronics, lasers, nonlinear optics, environmental optics, adaptive optics, and space@@ optics@@. Optics regarding the visible spectrum, infrared
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# Senate
# August 4, 1909, William C. White (D-18th district)@@ dies@@. His seat remained unfilled until the next
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  bills to be made in the Dáil or Seanad; thus the Parliamentary Counsel's role is@@ crucial@@.
#
# References
#
# External links
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# eman and Tony Camerino and directed by executive producer Chris Fisher. It aired on CBS in the United@@ States@@ and on CTV in Canada on May 3
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  only nine touchdowns, both of which remain program records. The team allowed zero passing touchdowns, which is@@ tied@@ for the program record.
#
# Frank Maher
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# @@Spect@@rum was an American subscription television channel that was
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# -pass filters that effectively reduce noise but also blur out the edges. However the Kuwahara@@ filter@@ is able to apply smoothing on the image
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  negotiated a two-year contract extension lasting until 30 June 2019.
#
# Squad
#
# New@@ contracts@@
#
# Last updated: 11 September 2017
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# abautermann", about the German water sprite of the same name, in the German publication Se@@eg@@emälde in 1828.
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ) is a Canadian-American philosopher best known for his neo-Hobbesian social contract (@@contract@@arian) theory of morality, as developed in
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Bisciglia was born in 1980, and raised primarily in Gig Harbor, Washington. B@@isc@@iglia attended the University of Washington from 1999
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  them.  Some ler can be very demanding.  The second type of ler are not@@ linked@@ to any specific place and can be more abstract
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Situated in the fertile grassland region – known as the Baie des Veys – which@@ constitutes@@ the joint estuary of four rivers, Is
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# La Vie miraculeuse de Thérèse Martin (The Mirac@@ulous@@ Life of Thérèse Martin), is
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  a bone is cut during surgery bleeding can be a difficult problem to control, especially in the highly vascular@@ bones@@ of the spine and sternum.  Ble
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  by Stan Lee and Gene Colan.
#
# Fictional character biography
#
# Origin
# A gigantic@@ android@@ that is thousands of years old, Ultimo
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  and leaves Caprica to return to the human fleet. Commander William Adama returns to command of the@@ fleet@@, but President Laura Roslin persuades almost
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  [one's] good pleasure') is less common but, in its Italian form , entered the musical@@ ling@@ua franca (see below).
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# REOC) was a case before the High Court of Australia determining that the HREOC could not@@ valid@@ly exercise judicial power. The High Court maintained
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  an American audio production company owned by Logitech that designs and produces microphones, headphones, recording tools,@@ signal@@ processors, and music accessories for audio professionals,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  and takes a darker turn than its predecessor.
#
# The series premiered on Cartoon Network in the United@@ States@@ on April 18, 2008, and on Tele
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  city attorney is elected for four years, and the city charter requires the city attorney to be a lawyer@@ qualified@@ to practice in the California courts for five years
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# "The Screwfly Solution" is a 1977 science fiction short story by R@@acco@@ona Sheldon, a pen name for American psychologist
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  and was a Research Scientist at Stanford University in artificial intelligence working with John McCarthy on Phenomenal Data@@ Mining@@ and Carolyn Talcott on theorem provers.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  risk management, standards, financing, and recovery mechanisms. It was launched by the Indian Prime Minister Narendra@@ Modi@@ at the 2019 UN Climate Action Summit in September
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Vipers players
# French Quebecers
# Ice hockey people from Quebec
# Louisiana IceGators (@@EC@@HL) players
# Philadelphia Bulldogs players
# R
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  a switched fabric. NBMA networks do support multicast or broadcast traffic manually (pseudo-broad@@casts@@). Some common examples of nonbroadcast network
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# " is the first episode of Friends tenth season. It first aired on the NBC network in the United@@ States@@ on September 25, 2003.
#
# Plot
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# is a Japanese actor and voice actor. The son of actor@@ Jun@@ Murakami and singer Ua, he
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Chief Justice of Samoa () is the chief justice of the Supreme Court of Samoa. The@@ qualifications@@ and powers of the office are governed by Part
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Boston, Massachusetts commonly known as the Manual of The Mother Church is the book that establishes the structure and@@ governs@@ The First Church of Christ, Scientist, also
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# rather than simply discrete segments of a text being in different languages). Hybrid words are effectively "internally@@ mac@@aronic." In spoken language, code-
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#
# In 1912, Russell published a compilation of quotations and selections from authors, philosophers, poets,@@ etc@@. entitled Golden Grain: Thoughts of Many Mind
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Child Lebensborn is a 2018 social simulation game developed by Teknopilot for iOS,@@ Android@@ and Windows. The player takes the role of
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# -renowned Riverdance.
#
# His first solo album A Connachtman's Ramb@@les@@ established him as a solo musician and proved a
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Evanger Power@@ Station@@  is a hydroelectric power station located in
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The International Rutabaga Cur@@ling@@ Championship takes place annually at the Ithaca
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  bis 1946
# Balke, Hilde (2001): Die Präsidenten des bayer@@isc@@hen Landtags von 1946 bis 1994, Bayer
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# , regulation, and fair distribution of risk in society. His recent research includes work on how private insurance@@ contracts@@ regulate individual and commercial behavior and on how public
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# etary spacecraft Galileo II carries Atom and his friends to Titan, a satellite of Saturn. However, what@@ awaits@@ them when they arrive there is an attack from
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  housing and roads.
#
# On 7 July 2021, during the first cabinet reshuffle of the Second@@ Modi@@ ministry, Giriraj Singh replaced Narendra Singh
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  frequency domain and their impulse responses in the time domain. Real-time implementations of such linear signal processing@@ filters@@ in the time domain are inevitably causal, an
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Nations theory can refer to:
#  Two-Nation Theory, the view that Muslims and Hindus in Colonial@@ India@@ were separate nations
#  Two Nations Theory (Ireland
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  (at Assington in Suffolk) to Brampton's older half-brother, John. Brampton@@ qualified@@ as a barrister, and in 1645
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  a novel by Valerio Massimo Manfredi
#  The Ends of the Earth (short story@@ collection@@), a story collection by Lucius Shepard
#  The
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Guide to the Galaxy. Named after or in honor of this:
#  "42"  (Doctor@@ Who@@), a 2007 television episode
#  "42
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# utes Études Scientifiques, with the help of the Centre National de la Recherche@@ Scient@@ifique. The journal was established in 1959
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Los Angeles, Chicago, San Francisco, Miami, Dallas, Houston, Washington, D.C.,@@ Boston@@, Orange County, Atlanta, and the Ham
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  with lyrics by Irshad Ahmed. The cast included Naseem Banu, Sohrab@@ Modi@@, Jagirdar, Sadiq Ali,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Banning's forces kill most of them, but the most dangerous one, Ethaniel, escapes and@@ teams@@ up with a human scientist, Dr. Laura
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Benben, Betsy Brantley and Matthias Hues. The film was released in the United@@ States@@ on September 28, 1990. The film is
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  2000 to 2003 he served as the board chair and president of the Canadian Medical Device Technology Association (MED@@EC@@) and presented MEDEC's submission to the
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ahn service S11, which links Aarau and Seuzach, and S29, which@@ links@@ Winterthur and Stein am Rhein.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# :
#  Axon (surname)
#  The Axons, an alien race from the Doctor@@ Who@@ adventure The Claws of Axos
#  Peter
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  early as the 11th century. Russian linguist Max Vasmer believes the word's etymology is@@ tied@@ to spali, a name for the defeated
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ile is a toy robot manufactured by sphero Ltd. The Roboreptile has infrared and sound@@ sensors@@, and is able to autonomously explore its
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  electoral college consisting of the elected members of the Parliament of India and the Legislative assemblies of the States of@@ India@@ and the Union territories (having an elected assembly
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# etary health refers to "the health of human civilization and the state of the natural systems on which it@@ depends@@". In 2015, the Rockefeller Foundation and The
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  and spiking neurons are examples of rhythmic phenomena, and can be considered as nonlinear limit cycle@@ oscill@@ators.
#
# History
# The theory of
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# weepers of the Japan Maritime Self-Defense Force.
#
# Development
# The experience of@@ mines@@weeping during the Korean War has made countries
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  worked with Italian wine, either in the trade or as a writer, since the early 1970s and@@ qualified@@ as a Master of Wine in 1980, the
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  at Boston College (USA).
#
# In 2017 he co-founded Quebec municipal party "Qué@@bec@@ 21" to challenge sitting mayor Régis
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# érica 1991 and Copa América 1993. He was also a member of the squad that@@ qualified@@ and participated in the 1994 FIFA World Cup.
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Emerald Cities Collaborative (@@EC@@C) is a national non-profit organization
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The ninth season of British science fiction television series Doctor@@ Who@@ began on 1 January 1972 with Day of the
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# . Block cellular automata are useful for simulations of physical quantities, because it is straightforward to choose transition@@ rules@@ that obey physical constraints such as reversibility and
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 's entries for the Eurovision Song Contest. As a member of the "Big 5", Germany automatically@@ qualifies@@ to compete in the final. In addition to
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# vision may refer to:
#
#  Provision (accounting), a term for liability in accounting
#  Provision (@@contract@@ing), a term for a procurement condition
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# : Requiem (2003)
#  The Cat Leaves Home (2004)
#  Animus Anima (@@2005@@)
#  Year One in the North (2005
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  GT racing team that competes in blue-riband motorsport events throughout Europe including the FIA W@@EC@@ Super Season and the 24 hours of Le Mans
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The 1993 Lipton Championships was a tennis tournament played on Hard courts in Key B@@isc@@ayne, Florida, United States the event was
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
#  Minbo (1992)
#  Nin x Nin: Ninja Hattori-kun, the Movie (@@2004@@) as Jinzo Hattori
#  The U
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  British comedy feature film Bill, which he also developed with writers Laurence Rickard and Ben Willb@@ond@@
# . Bill was Bracewell's
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# The Sixth Extinction: An Un@@natural@@ History is a 2014 non-fiction book written
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  version with English lyrics by Australian lyricist Dorothy Dodd; and instrumental versions in jazz, pop, easy@@ listening@@, flamenco or rock styles. Other
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  officer of state to another. Particularly in parliamentary systems of government, heads of state often act on the@@ basis@@ of advice issued by prime ministers or other government
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Theatre companies in Los Angeles
# Theatre in Los Angeles
# Regional theatre in the United@@ States@@
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# . She played the title character in four series of Bramwell, and has a recurring role in Doctor@@ Who@@ as Kate Stewart, Head of Scientific Research at
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Magda's love, he gets very sick with an illness, requiring him to go to the United@@ States@@ for treatment. However, he chose not tell
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  for the dual purposes of regaining her place in the syndicate, and gaining protection from Scion.@@ When@@ Hector—the Underking—is found murdered
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# : Accounts; Agriculture; Banks and Banking; Claims; Education; Federal Relations; Fisheries; Library;@@ Manufact@@ures; Mercantile Affairs and Insurance;
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  VHS and Laserdisc.
#
# The original version was released by Virgin Records in 1988, and@@ ties@@ in with the compilation album of the same name
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  in electrical and electronic engineering.
#
# Prior to 1870
# 1745–1746 – Leyden@@ jar@@ capacitor by Ewald Georg von Kleist and
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Express, where for thirty years he was the right-hand man of the late editor in chief John@@ Jun@@or.
#
# As features editor
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  games
# Run and gun games
# Side-scrolling video games
# Video games developed in the United@@ States@@
# Video games about zombies
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  to her marriage, yet she decides to stay.
#
# Critical reception
# Time magazine explained that S@@ond@@heim is "still the great chronicler of
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Eighteen ships of the Royal@@ Navy@@ have borne the name HMS Fly:
#
#
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  known as limited field of view (LFV) reconstruction) is a technique to correct truncation@@ artifacts@@ caused by limiting image data to a small field
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Visconti, record producer to David Bowie among others, and became the studio manager of V@@isc@@onti's 'Good Earth Studios' in
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  British children's television series
# 2005 British television series debuts
# 2006 British television series endings
# BBC@@ children@@'s television shows
# English-language television shows
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# 1992) and 740 (1992), and considering that the situation in the Socialist Federal Republic of Yugoslavia@@ constitutes@@ a threat to international peace and stability, the
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  its preservation of the original and tragic ending. The two main protagonists are the youngest daughter of the royal@@ family@@, Marina, and her best friend Fritz,
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#  Sentai Gingaman, and  he reprised the role in two Super Sentai Series V-@@C@@inema Films: Gogo V Vs Ging
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
